# %%
import nltk
import random
from nltk.corpus import movie_reviews

# %% [markdown]
# Using the movie reviws dataset to classify them into positive or negative review

# %%
movie_reviews.categories()
# Out:
# ['neg', 'pos']

# %%
documents = [(list(movie_reviews.words(fileid)), category)
             for category in movie_reviews.categories()
             for fileid in movie_reviews.fileids(category)]

random.shuffle(documents)

print(documents[1])#where the first element is a list the words, and the 2nd element is the "pos" or "neg" label.
# Out:
# (['airplane', '!', 'is', 'considered', 'among', 'many', 'to', 'be', 'the', 'epitome', 'of', 'satire', 'film', '-', 'making', '.', 'after', 'all', ',', 'it', "'", 's', 'brought', 'to', 'us', 'by', 'one', 'of', 'the', 'best', 'known', 'satire', 'writing', '/', 'directing', 'teams', '.', 'even', 'if', 'most', 'people', 'don', "'", 't', 'recognize', 'the', 'names', 'behind', 'the', 'films', ',', 'they', 'are', 'bound', 'to', 'recognize', 'the', 'titles', ':', 'airplane', '!', ',', 'top', 'secret', ',', 'the', 'naked', 'gun', ',', 'and', 'hot', 'shots', 'to', 'name', 'a', 'few', '.', 'but', 'although', 'the', 'zucker', '/', 'abrahams', '/', 'zucker', 'team', 'was', 'first', 'introduced', 'with', 'the', 'kentucky', 'fried', 'movie', 'in', '1977', ',', 'airplane', '!', 'remains', 'the', 'true', 'cornerstone', 'of', 'their', 'work', ',', 'and', 'their', 'directorial', 'debuts', '.', 'in', 'the', 'seventies', ',', 'disaster', 'films', 'seemed', 'to', 'be', 'at', 'an', 'all', 'time', 'high', '
# ...

# %%
all_words = []
for w in movie_reviews.words():
    all_words.append(w.lower())

all_words = nltk.FreqDist(all_words)
print(all_words.most_common(15))
print(all_words["stupid"])
# Out:
# [(',', 77717), ('the', 76529), ('.', 65876), ('a', 38106), ('and', 35576), ('of', 34123), ('to', 31937), ("'", 30585), ('is', 25195), ('in', 21822), ('s', 18513), ('"', 17612), ('it', 16107), ('that', 15924), ('-', 15595)]
# 253

# %%
type(all_words)
# Out:
# nltk.probability.FreqDist

# %%
word_features = list(all_words.keys())[:3000]
word_features
# Out:
# ['plot',
#  ':',
#  'two',
#  'teen',
#  'couples',
#  'go',
#  'to',
#  'a',
#  'church',
#  'party',
#  ',',
#  'drink',
#  'and',
#  'then',
#  'drive',
#  '.',
#  'they',
#  'get',
#  'into',
#  'an',
#  'accident',
#  'one',
#  'of',
#  'the',
#  'guys',
#  'dies',
#  'but',
#  'his',
#  'girlfriend',
#  'continues',
#  'see',
#  'him',
#  'in',
#  'her',
#  'life',
#  'has',
#  'nightmares',
#  'what',
#  "'",
#  's',
#  'deal',
#  '?',
#  'watch',
#  'movie',
#  '"',
#  'sorta',
#  'find',
#  'out',
#  'critique',
#  'mind',
#  '-',
#  'fuck',
#  'for',
#  'generation',
#  'that',
#  'touches',
#  'on',
#  'very',
#  'cool',
#  'idea',
#  'presents',
#  'it',
#  'bad',
#  'package',
#  'which',
#  'is',
#  'makes',
#  'this',
#  'review',
#  'even',
#  'harder',
#  'write',
#  'since',
#  'i',
#  'generally',
#  'applaud',
#  'films',
#  'attempt',
#  'break',
#  'mold',
#  'mess',
#  'with',
#  'your',
#  'head',
#  'such',
#  '(',
#  'lost',
#  'highway',
#  '&',
# ...

# %%
def find_features(document):
    words = set(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features

# %%
print((find_features(movie_reviews.words('neg/cv000classifier = nltk.NaiveBayesClassifier.train(training_set)
_29416.txt'))))
# Out:
# {'plot': True, ':': True, 'two': True, 'teen': True, 'couples': True, 'go': True, 'to': True, 'a': True, 'church': True, 'party': True, ',': True, 'drink': True, 'and': True, 'then': True, 'drive': True, '.': True, 'they': True, 'get': True, 'into': True, 'an': True, 'accident': True, 'one': True, 'of': True, 'the': True, 'guys': True, 'dies': True, 'but': True, 'his': True, 'girlfriend': True, 'continues': True, 'see': True, 'him': True, 'in': True, 'her': True, 'life': True, 'has': True, 'nightmares': True, 'what': True, "'": True, 's': True, 'deal': True, '?': True, 'watch': True, 'movie': True, '"': True, 'sorta': True, 'find': True, 'out': True, 'critique': True, 'mind': True, '-': True, 'fuck': True, 'for': True, 'generation': True, 'that': True, 'touches': True, 'on': True, 'very': True, 'cool': True, 'idea': True, 'presents': True, 'it': True, 'bad': True, 'package': True, 'which': True, 'is': True, 'makes': True, 'this': True, 'review': True, 'even': True, 'harder': True, 'w
# ...

# %%
featuresets = [(find_features(rev), category) for (rev, category) in documents]
len(featuresets)
# Out:
# 2000

# %%
#Splitting the data into train and test
training_set = featuresets[:1900]
testing_set = featuresets[1900:]

# %% [markdown]
# ###  Classification using NaiveBayes

# %%
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
print("Classifier accuracy percent:",(nltk.classify.accuracy(classifier, testing_set))*100)
# Out:
# Classifier accuracy percent: 84.0

# %%
#the most valuable words are when it comes to positive or negative reviews:
classifier.show_most_informative_features(15)
# Out:
# Most Informative Features
#                    sucks = True              neg : pos    =     17.5 : 1.0
#                   annual = True              pos : neg    =      9.1 : 1.0
#                  frances = True              pos : neg    =      9.1 : 1.0
#            unimaginative = True              neg : pos    =      8.3 : 1.0
#              silverstone = True              neg : pos    =      7.6 : 1.0
#                  idiotic = True              neg : pos    =      7.2 : 1.0
#                     mena = True              neg : pos    =      6.9 : 1.0
#               schumacher = True              neg : pos    =      6.9 : 1.0
#                   shoddy = True              neg : pos    =      6.9 : 1.0
#                   suvari = True              neg : pos    =      6.9 : 1.0
#                    kudos = True              pos : neg    =      6.7 : 1.0
#                atrocious = True              neg : pos    =      6.5 : 1.0
# ...

# %% [markdown]
# What this tells you is the ratio of occurences in negative to positive, or visa versa, for every word.

# %% [markdown]
# ### Saving the Classifier
# Instead of training the classifier everytime we wan tto use it, we should rather save the classifier using the pickle module.
# <br> For that, we will open a pickle file in 'wb' mode, dump the classifier there and close the file.
# <br> To retrieve, open the file in 'rb' mode, load the classifier and close.
# ***
# <div class="alert alert-block alert-warning">
# <b>Warning:</b> The pickle module is not secure.<b>Only unpickle data you trust.</b>
# It is possible to construct malicious pickle data which will execute arbitrary code during unpickling. Never unpickle data that could have come from an untrusted source, or that could have been tampered with.
# Consider signing data with hmac if you need to ensure that it has not been tampered with.
# Safer serialization formats such as json may be more appropriate if you are processing untrusted data.
# </div>
# <br> For more details on pickle refer <a href="https://docs.python.org/3/library/pickle.html">[Pickle Documentation]</a>

# %%
import pickle

# %%
save_classifier = open("naivebayes_nlp_txt_clsf.pickle","wb")
pickle.dump(classifier, save_classifier)
save_classifier.close()

# %%
classifier_f = open("naivebayes_nlp_txt_clsf.pickle", "rb")
classifier = pickle.load(classifier_f)
classifier_f.close()

# %%
classifier.most_informative_features(n=10)
# Out:
# [('sucks', True),
#  ('annual', True),
#  ('frances', True),
#  ('unimaginative', True),
#  ('silverstone', True),
#  ('idiotic', True),
#  ('mena', True),
#  ('schumacher', True),
#  ('shoddy', True),
#  ('suvari', True)]

# %%
classifier.labels()
# Out:
# ['neg', 'pos']
